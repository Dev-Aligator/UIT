# %% [markdown]
# # CS431 - CÁC KỸ THUẬT HỌC SÂU VÀ ỨNG DỤNG
#
# **Hướng dẫn**:
# - Khởi động kernel: Ở thanh menu, chọn Kernel$\rightarrow$Restart kernel.
# - Hoàn tất tất cả các mục có comment `YOUR CODE HERE`
# - Chạy toàn bộ các block code để kiểm tra: Ở thanh menu, chọn Cell$\rightarrow$Run All.

# %% [markdown]
# ---

# %% [markdown]
# # CÀI ĐẶT MÔ HÌNH NEURAL NETWORK VỚI KERAS

# %% [markdown]
# Một mô hình máy học cần có đủ ít nhất 7 phương thức sau:
# - `__init__`: hàm constructor trong hướng đối tượng, được sử dụng để khởi tạo các tham số mặc định hoặc tham số bắt đầu một mô hình. Trong những bài tập đầu tiên, để đơn giản constructor sẽ không sử dụng.
# - `build`: xây dựng kiến trúc của mô hình
# - `train`: bắt đầu quá trình huấn luyện mô hình
# - `save`: lưu lại mô hình sau khi đã huấn luyện
# - `load`: load lên mô hình từ file đã huấn luyện (pretrained)
# - `summary`: in tóm tắt kiến trúc mô hình
# - `predict`: dự đoán giá trị output từ dữ liệu đầu vào

# %%
# Mô hình cài đặt tổng quát bao gồm 7 phương thức cơ bản
# Lưu ý: mô hình này chỉ mang tính gợi ý, không bắt buộc
# Tuy nhiên, trong phần bài tập cần tuân theo các tên phương thức này
class MyModel:
    # constructor
    def __init__(self):
        return None

    # Implement architecture of the model
    def build(self):
        return None

    # Train the defined model with training and validation data
    def train(self):
        return None

    # Save the trained model to file
    def save(self, model_path):
        return None

    # Load pretrained model from file
    def load(self):
        return None
    # Visualize your model
    def summary(self):
        return None

    # Apply your model with new input data
    def predict(self):
        return None

# %% [markdown]
# ## 1. Import các thư viện Keras
#
# Đầu tiên, ta sẽ import các thư viện, module, hàm của `Keras`:
# - `Input`: để nhận dữ liệu đầu vào cho mô hình
# - `Dense`: hay còn gọi là lớp Fully Connected (Lớp kết nối đầy đủ), một thành phần quan trọng của các mô hình dựa trên mạng Neural Network.
# - `Model`: đây là lớp đối tượng mô hình được sử dụng để đóng gói lớp đầu vào, đầu ra, sau đó huấn luyện với phương thức `fit` và dự đoán kết quả với `predict`.
# - `load_model`: hàm sử dụng để load mô hình lên từ file

# %%
from keras.layers import Input, Dense
from keras import Model
import tensorflow as tf
from keras.models import load_model
import numpy as np

# %% [markdown]
# ## 2. Cài đặt mô hình Neural Network
# Tiếp theo, ta sẽ dựa trên khung đối tượng `MyModel` đã trình bày ở mục trước để tiến hành cài đặt mô hình **Neural Network**. Phương thức chính mà bài tập này cần thực hiện là `def build()`. Các phương thức còn lại đã được cài đặt sẵn, các bạn cần đọc, hiểu ý nghĩa và cách thức sử dụng về sau.

# %% [markdown]
# ![NeuralNet.png](data:image/png;base64,...)

# %%
# Neural Network
class NeuralNetwork:
    def __init__(self): # Self is similar to your 'this' pointer in C++
        return None

    def build(self, input_dim, output_dim, n_hidden, n_neurons):
        # `input_dim`: kích thước input feature
        # `output_dim`: số phân lớp cần phân loại
        # `n_hidden`: số lượng lớp ẩn
        # `n_neurons`: số lượng neuron mỗi lớp ẩn

        # Khởi tạo model
        self.model = None

        # Hãy cài đặt để định nghĩa KIẾN TRÚC MÔ HÌNH và lưu ở thuộc tính `self.model`
        # với các biến đối tượng sau:
        #  - tạo biến `input` với lớp đối tượng `Input` của Keras,
        #    truyền vào kích thước đầu vào `input_dim`
        #  - tạo `n_hidden`lớp ẩn biết rằng, mỗi lớp ẩn có `n_neurons`, có sử dụng bias
        #    activation là hàm `sigmoid`. Đầu ra của lớp ẩn này là đầu vào lớp ẩn sau.
        #  - tạo biến `output` với lớp đối tượng `Dense` của Keras,
        #    truyền vào các tham số:  kích thước output (chú ý PHÂN LOẠI ĐA LỚP),
        #    có sử dụng bias, CÓ SỬ DỤNG hàm activation là `softmax`. Đầu vào của lớp
        #    output chính là lớp ẩn cuối cùng.
        # Sau bước này, self.model sẽ đóng gói 2 biến `input` và `output` để tạo thành mô hình

        # YOUR CODE HERE
        #raise NotImplementedError()

        inputs = Input(shape=(input_dim,))

        # Initialize the output of the first hidden layer to be the input
        x = inputs

        # Define the hidden layers
        for _ in range(n_hidden):
            x = Dense(n_neurons, activation='sigmoid', use_bias=True)(x)

        # Define the output layer
        output = Dense(output_dim, activation='softmax', use_bias=True)(x)

        # Define the model using the input and output layers
        self.model = Model(inputs=inputs, outputs=output)

        return self.model

    def train(self, x_train, y_train, epochs=500):
        # Khởi tạo mặc định với số `epochs=50`, `learning_rate=0.05`
        opt = tf.keras.optimizers.SGD(learning_rate=0.05) # Stochastic Gradient Descent
        self.model.compile(optimizer=opt, loss='categorical_crossentropy') # CCE loss
        return self.model.fit(x_train, y_train, epochs=epochs)

    def save(self, model_file):
        return self.model.save(model_file)

    def load(self, model_file):
        self.model = load_model(model_file)

    def summary(self):
        self.model.summary()

    def predict(self, x_test):
        return self.model.predict(x_test)

    def get_weights(self, layer_id):
        return self.model.layers[layer_id].get_weights()

# %% [markdown]
# Tiếp theo, ta sẽ khởi tạo đối tượng NeuralNetwork và kiểm tra thử xem phương `build` đã cài đặt chính xác chưa.

# %%
nn = NeuralNetwork()
# Trong ví dụ này, ta sẽ khởi tạo input là một vector 1000 chiều,
# bài toán cần phân loại 20 lớp đối tượng. Số lượng lớp ẩn là 3
# và số neuron mỗi lớp ẩn là  10.
nn.build(1000, 20, 3, 10)
nn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 1000)]            0
#
#  dense_4 (Dense)             (None, 10)                10010
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 20)                220
#
# =================================================================
# Total params: 10450 (40.82 KB)
# Trainable params: 10450 (40.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Kiểm tra sơ bộ kiến trúc mạng gồm 2 + 3 = 5 lớp: Input, 3 lớp ẩn và Output
assert len(nn.model.layers)==5
assert str(type(nn.model.layers[0])).endswith("input_layer.InputLayer'>") == True
assert str(type(nn.model.layers[1])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[2])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[3])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[4])).endswith("core.dense.Dense'>") == True
assert nn.model.layers[0].input_shape[0][1] == 1000
assert nn.model.layers[-1].output_shape[1] == 20
assert nn.model.layers[1].use_bias == True

# %%
# Kiểm tra với bộ test ẩn

# %% [markdown]
# ## 3. Tạo dữ liệu mẫu (toy example)
# Bước tiếp theo, ta sẽ tiến hành tạo mẫu dữ liệu để huấn luyện và kiểm thử.
#
# Dữ liệu được tạo ra là các điểm rải ngẫu nhiên xung quanh 4 cụm điểm:
# - [10, -2]
# - [2, 8]
# - [12, 8]
# - [-2, 0]
#
# Lưu ý rằng, 4 cụm điểm này rời nhau đủ xa để khi thêm nhiễu ngẫu nhiên,
# các điểm thuộc 4 cụm này vẫn không giao thoa nhau.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Số phân lớp: 4
K = 4
# Tạo bộ dữ  liệu gồm 4 điểm
# S1, S2, S3, S4 là tâm của 4 lớp
S1= np.array([[10,-2]])
S2= np.array([[2,8]])
S3= np.array([[12,8]])
S4= np.array([[-2,0]])

# 50 samples mỗi lớp
n_sample = 50
# Phát sinh các điểm với nhiễu ngẫu nhiên xung quanh 4 tâm
pts1 = S1 + np.random.normal(0, 1.5, size=(n_sample,2))
pts2 = S2 + np.random.normal(0, 1.5, size=(n_sample,2))
pts3 = S3 + np.random.normal(0, 1.5, size=(n_sample,2))
pts4 = S4 + np.random.normal(0, 1.5, size=(n_sample,2))

# Nối tất cả các mẫu thành một khối dữ liệu X (input feature) và Y (nhãn)
X_train = np.concatenate((pts1, pts2, pts3, pts4))
# Concatenate data labels to a single input variable Y
Y_train = np.concatenate(([0]*n_sample, [1]*n_sample, [2]*n_sample, [3]*n_sample))

# Chuyển Y từ dạng nhãn sang one-hot vector
Y_train = Y_train.astype(int)
Y_oh = np.zeros((Y_train.size, Y_train.max()+1 ))
Y_oh[np.arange(Y_train.size), Y_train] = 1

# Trực quan hóa dữ liệu bằng các hình tròn màu đỏ, xanh lá, xanh dương và vàng
plt.plot(pts1[:,0], pts1[:,1], 'ro')
plt.plot(pts2[:,0], pts2[:,1], 'go')
plt.plot(pts3[:,0], pts3[:,1], 'bo')
plt.plot(pts4[:,0], pts4[:,1], 'yo')
plt.show()

# %% [markdown]
# ## 4. Huấn luyện mô hình với dữ liệu mẫu
#
# Tiếp theo, ta sẽ khởi tạo lại mô hình để phù hợp với dữ liệu mẫu đã phát sinh ở bước trước. Việc xây dựng kiến trúc của mô hình phải phù hợp với số chiều của dữ liệu mẫu.

# %%
nn = NeuralNetwork()

# Hãy gọi phương thức `build` cho đối tượng `sr` và truyền tham số đầu vào
# tương ứng với dữ liệu train đã phát sinh ở code block trên
# Theo bạn, `input_dim`, `output_dim` bằng bao nhiêu?
# Đối với các lớp ẩn, ta khởi tạo 01 lớp ẩn và 03 neuron cho mỗi lớp ẩn

# YOUR CODE HERE
nn.build(2,4,1,3)
#raise NotImplementedError()



# Để hiển thị kiến trúc của mô hình ta gọi phương thức `summary`
print("Kiến trúc của mô hình Neural Network: ")
nn.summary()
# Out:
# Kiến trúc của mô hình Neural Network:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 2)]               0
#
#  dense_8 (Dense)             (None, 3)                 9
#
#  dense_9 (Dense)             (None, 4)                 16
#
# =================================================================
# Total params: 25 (100.00 Byte)
# Trainable params: 25 (100.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Kiểm tra kết quả khi đối tượng `nn` gọi phương thức `build`
assert len(nn.model.layers)==3
assert str(type(nn.model.layers[0])).endswith("input_layer.InputLayer'>") == True
assert str(type(nn.model.layers[1])).endswith("core.dense.Dense'>") == True
assert str(type(nn.model.layers[2])).endswith("core.dense.Dense'>") == True

# Check shapes
assert nn.model.layers[0].input_shape[0][1] == 2
assert nn.model.layers[1].output_shape[1] == 3
assert nn.model.layers[2].output_shape[1] == 4

# Check activation
assert abs(nn.model.layers[1].activation(1.0).numpy() - 0.7310586)<0.00000001
assert abs(nn.model.layers[1].activation(-1.0).numpy() - 0.26894143)<0.00000001
inputs = tf.random.normal(shape=(32, 10))
assert np.mean(abs(nn.model.layers[2].activation(inputs).numpy() -
                   tf.keras.activations.softmax(inputs).numpy()))<0.00001

# Check bias
assert nn.model.layers[1].use_bias == True
assert nn.model.layers[2].use_bias == True

# %%
# Để huấn luyện mô hình ta gọi phương thức `train` với dữ liệu mẫu đã tạo được
# Nếu bước `build` mô hình gọi đúng thì bước `train` sau sẽ thực hiện thành công
# LƯU Ý: Ở đây ta sử dụng output là Y_oh dạng one-hot thay vì dạng nhãn (label)
hist = nn.train(X_train, Y_oh)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 1s 4ms/step - loss: 1.6247
# Epoch 2/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4934
# Epoch 3/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4079
# Epoch 4/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3405
# Epoch 5/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2929
# Epoch 6/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.2638
# Epoch 7/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2382
# Epoch 8/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2191
# Epoch 9/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2023
# Epoch 10/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1867
# Epoch 11/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1742
# Epoch 12/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1604
# Epoch 13/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1477
# Epoch 14/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1340
# Epoch 15/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1217
# Epoch 16/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1114
# Epoch 17/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0993
# Epoch 18/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0878
# Epoch 19/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0765
# Epoch 20/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0653
# Epoch 21/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0557
# Epoch 22/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0458
# Epoch 23/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0358
# Epoch 24/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0262
# Epoch 25/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.0166
# Epoch 26/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0097
# Epoch 27/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0007
# Epoch 28/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9908
# Epoch 29/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9824
# Epoch 30/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9726
# Epoch 31/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9642
# Epoch 32/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9564
# Epoch 33/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9494
# Epoch 34/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9412
# Epoch 35/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9356
# Epoch 36/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.9257
# Epoch 37/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9176
# Epoch 38/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9105
# Epoch 39/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9035
# Epoch 40/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8959
# Epoch 41/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8897
# Epoch 42/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8831
# Epoch 43/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8758
# Epoch 44/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8702
# Epoch 45/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8633
# Epoch 46/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8573
# Epoch 47/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8512
# Epoch 48/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8442
# Epoch 49/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8381
# Epoch 50/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8324
# Epoch 51/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8264
# Epoch 52/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8213
# Epoch 53/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8155
# Epoch 54/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8094
# Epoch 55/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8044
# Epoch 56/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.8000
# Epoch 57/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7941
# Epoch 58/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7884
# Epoch 59/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7837
# Epoch 60/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7782
# Epoch 61/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7724
# Epoch 62/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7676
# Epoch 63/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7619
# Epoch 64/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7571
# Epoch 65/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7526
# Epoch 66/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7480
# Epoch 67/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7432
# Epoch 68/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7383
# Epoch 69/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7338
# Epoch 70/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7293
# Epoch 71/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7243
# Epoch 72/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7190
# Epoch 73/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7139
# Epoch 74/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7084
# Epoch 75/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7036
# Epoch 76/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6960
# Epoch 77/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6889
# Epoch 78/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6810
# Epoch 79/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6720
# Epoch 80/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6614
# Epoch 81/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6508
# Epoch 82/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6399
# Epoch 83/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6289
# Epoch 84/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6176
# Epoch 85/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6077
# Epoch 86/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5978
# Epoch 87/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5888
# Epoch 88/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5804
# Epoch 89/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5713
# Epoch 90/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5620
# Epoch 91/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5540
# Epoch 92/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5464
# Epoch 93/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5378
# Epoch 94/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5305
# Epoch 95/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5234
# Epoch 96/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5160
# Epoch 97/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5088
# Epoch 98/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5019
# Epoch 99/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4954
# Epoch 100/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4890
# Epoch 101/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4824
# Epoch 102/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4765
# Epoch 103/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4700
# Epoch 104/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4640
# Epoch 105/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4584
# Epoch 106/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4528
# Epoch 107/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4468
# Epoch 108/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4413
# Epoch 109/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4358
# Epoch 110/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4303
# Epoch 111/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4250
# Epoch 112/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4204
# Epoch 113/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4151
# Epoch 114/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4101
# Epoch 115/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4054
# Epoch 116/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4008
# Epoch 117/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3963
# Epoch 118/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3916
# Epoch 119/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3873
# Epoch 120/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3829
# Epoch 121/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3786
# Epoch 122/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3746
# Epoch 123/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3704
# Epoch 124/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3665
# Epoch 125/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3625
# Epoch 126/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3587
# Epoch 127/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3551
# Epoch 128/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3515
# Epoch 129/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3477
# Epoch 130/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3442
# Epoch 131/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3404
# Epoch 132/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3370
# Epoch 133/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3337
# Epoch 134/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3302
# Epoch 135/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3270
# Epoch 136/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3237
# Epoch 137/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3206
# Epoch 138/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3174
# Epoch 139/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3143
# Epoch 140/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3113
# Epoch 141/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3082
# Epoch 142/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3053
# Epoch 143/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3025
# Epoch 144/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2997
# Epoch 145/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2970
# Epoch 146/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2942
# Epoch 147/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2918
# Epoch 148/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2888
# Epoch 149/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2861
# Epoch 150/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2836
# Epoch 151/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2811
# Epoch 152/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2787
# Epoch 153/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2761
# Epoch 154/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2736
# Epoch 155/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2715
# Epoch 156/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2691
# Epoch 157/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2668
# Epoch 158/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2645
# Epoch 159/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2624
# Epoch 160/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2603
# Epoch 161/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2579
# Epoch 162/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2558
# Epoch 163/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2538
# Epoch 164/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2517
# Epoch 165/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2496
# Epoch 166/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2475
# Epoch 167/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2457
# Epoch 168/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2438
# Epoch 169/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2417
# Epoch 170/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2399
# Epoch 171/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2379
# Epoch 172/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2363
# Epoch 173/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2342
# Epoch 174/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2324
# Epoch 175/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2307
# Epoch 176/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2290
# Epoch 177/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2273
# Epoch 178/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2256
# Epoch 179/500
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2238
# Epoch 180/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2222
# Epoch 181/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2205
# Epoch 182/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2188
# Epoch 183/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2173
# Epoch 184/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2159
# Epoch 185/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2142
# Epoch 186/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2127
# Epoch 187/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2111
# Epoch 188/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2096
# Epoch 189/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2080
# Epoch 190/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2066
# Epoch 191/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2052
# Epoch 192/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2038
# Epoch 193/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2023
# Epoch 194/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2010
# Epoch 195/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1996
# Epoch 196/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1984
# Epoch 197/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1969
# Epoch 198/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1957
# Epoch 199/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1943
# Epoch 200/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1929
# Epoch 201/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1916
# Epoch 202/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1903
# Epoch 203/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1892
# Epoch 204/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1881
# Epoch 205/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1870
# Epoch 206/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1856
# Epoch 207/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1844
# Epoch 208/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1834
# Epoch 209/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1821
# Epoch 210/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1809
# Epoch 211/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1798
# Epoch 212/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1788
# Epoch 213/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1777
# Epoch 214/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1766
# Epoch 215/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1755
# Epoch 216/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1745
# Epoch 217/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1735
# Epoch 218/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1724
# Epoch 219/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1713
# Epoch 220/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1704
# Epoch 221/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1696
# Epoch 222/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1684
# Epoch 223/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1675
# Epoch 224/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1665
# Epoch 225/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1655
# Epoch 226/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1646
# Epoch 227/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1638
# Epoch 228/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1628
# Epoch 229/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1618
# Epoch 230/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1610
# Epoch 231/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1601
# Epoch 232/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1592
# Epoch 233/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1585
# Epoch 234/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1575
# Epoch 235/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1567
# Epoch 236/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1558
# Epoch 237/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1548
# Epoch 238/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1540
# Epoch 239/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1532
# Epoch 240/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1525
# Epoch 241/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1516
# Epoch 242/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1507
# Epoch 243/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1500
# Epoch 244/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1491
# Epoch 245/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1485
# Epoch 246/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1476
# Epoch 247/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1468
# Epoch 248/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1461
# Epoch 249/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1454
# Epoch 250/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1446
# Epoch 251/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1440
# Epoch 252/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1433
# Epoch 253/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1425
# Epoch 254/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1419
# Epoch 255/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1410
# Epoch 256/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1403
# Epoch 257/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1397
# Epoch 258/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1391
# Epoch 259/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1383
# Epoch 260/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1377
# Epoch 261/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1369
# Epoch 262/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1363
# Epoch 263/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1356
# Epoch 264/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1350
# Epoch 265/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1343
# Epoch 266/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1337
# Epoch 267/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1330
# Epoch 268/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1325
# Epoch 269/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1319
# Epoch 270/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1313
# Epoch 271/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1307
# Epoch 272/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1299
# Epoch 273/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1293
# Epoch 274/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1289
# Epoch 275/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1282
# Epoch 276/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1277
# Epoch 277/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1271
# Epoch 278/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1264
# Epoch 279/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1259
# Epoch 280/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1253
# Epoch 281/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1247
# Epoch 282/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1242
# Epoch 283/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1236
# Epoch 284/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1231
# Epoch 285/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1226
# Epoch 286/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1220
# Epoch 287/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1215
# Epoch 288/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1210
# Epoch 289/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1204
# Epoch 290/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1199
# Epoch 291/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1193
# Epoch 292/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1188
# Epoch 293/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1183
# Epoch 294/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1179
# Epoch 295/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1173
# Epoch 296/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1167
# Epoch 297/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1162
# Epoch 298/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1157
# Epoch 299/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1152
# Epoch 300/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1148
# Epoch 301/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1142
# Epoch 302/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1138
# Epoch 303/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1134
# Epoch 304/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1129
# Epoch 305/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1124
# Epoch 306/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1120
# Epoch 307/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1115
# Epoch 308/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1111
# Epoch 309/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1106
# Epoch 310/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1102
# Epoch 311/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1097
# Epoch 312/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1093
# Epoch 313/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1089
# Epoch 314/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1084
# Epoch 315/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1080
# Epoch 316/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1075
# Epoch 317/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1072
# Epoch 318/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1068
# Epoch 319/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1063
# Epoch 320/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1058
# Epoch 321/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1054
# Epoch 322/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1049
# Epoch 323/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1046
# Epoch 324/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1042
# Epoch 325/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1038
# Epoch 326/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1035
# Epoch 327/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1030
# Epoch 328/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1026
# Epoch 329/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1023
# Epoch 330/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1019
# Epoch 331/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1015
# Epoch 332/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1011
# Epoch 333/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1008
# Epoch 334/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1004
# Epoch 335/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1002
# Epoch 336/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0997
# Epoch 337/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0993
# Epoch 338/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0989
# Epoch 339/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0985
# Epoch 340/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0982
# Epoch 341/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0977
# Epoch 342/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0975
# Epoch 343/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0971
# Epoch 344/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0967
# Epoch 345/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0964
# Epoch 346/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0961
# Epoch 347/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0956
# Epoch 348/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0954
# Epoch 349/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0950
# Epoch 350/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0946
# Epoch 351/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0944
# Epoch 352/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0940
# Epoch 353/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0936
# Epoch 354/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0933
# Epoch 355/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0930
# Epoch 356/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 357/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0923
# Epoch 358/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0920
# Epoch 359/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0917
# Epoch 360/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0914
# Epoch 361/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0911
# Epoch 362/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0908
# Epoch 363/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0905
# Epoch 364/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0901
# Epoch 365/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0898
# Epoch 366/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0895
# Epoch 367/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0893
# Epoch 368/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0889
# Epoch 369/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0887
# Epoch 370/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0884
# Epoch 371/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0881
# Epoch 372/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0878
# Epoch 373/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0875
# Epoch 374/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0873
# Epoch 375/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0870
# Epoch 376/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0867
# Epoch 377/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0864
# Epoch 378/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0861
# Epoch 379/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0858
# Epoch 380/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0855
# Epoch 381/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0853
# Epoch 382/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0849
# Epoch 383/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0846
# Epoch 384/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0844
# Epoch 385/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0841
# Epoch 386/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0839
# Epoch 387/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0837
# Epoch 388/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0834
# Epoch 389/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0830
# Epoch 390/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0828
# Epoch 391/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0825
# Epoch 392/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0822
# Epoch 393/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0820
# Epoch 394/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0817
# Epoch 395/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0815
# Epoch 396/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0813
# Epoch 397/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0810
# Epoch 398/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0807
# Epoch 399/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0805
# Epoch 400/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0802
# Epoch 401/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0799
# Epoch 402/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0798
# Epoch 403/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0795
# Epoch 404/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0793
# Epoch 405/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0790
# Epoch 406/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0788
# Epoch 407/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0786
# Epoch 408/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0783
# Epoch 409/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0781
# Epoch 410/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0779
# Epoch 411/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0776
# Epoch 412/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0775
# Epoch 413/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0772
# Epoch 414/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0769
# Epoch 415/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0767
# Epoch 416/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0765
# Epoch 417/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0763
# Epoch 418/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0760
# Epoch 419/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0759
# Epoch 420/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0756
# Epoch 421/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0754
# Epoch 422/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0751
# Epoch 423/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0749
# Epoch 424/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0747
# Epoch 425/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0745
# Epoch 426/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0744
# Epoch 427/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0741
# Epoch 428/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0739
# Epoch 429/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0737
# Epoch 430/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0735
# Epoch 431/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0732
# Epoch 432/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0731
# Epoch 433/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0728
# Epoch 434/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0726
# Epoch 435/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0724
# Epoch 436/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0722
# Epoch 437/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0720
# Epoch 438/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0717
# Epoch 439/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0716
# Epoch 440/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0714
# Epoch 441/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0712
# Epoch 442/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0710
# Epoch 443/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0709
# Epoch 444/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0707
# Epoch 445/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0703
# Epoch 446/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0702
# Epoch 447/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0700
# Epoch 448/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0698
# Epoch 449/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0697
# Epoch 450/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0695
# Epoch 451/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0693
# Epoch 452/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0691
# Epoch 453/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0689
# Epoch 454/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0687
# Epoch 455/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0685
# Epoch 456/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0683
# Epoch 457/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0681
# Epoch 458/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0679
# Epoch 459/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0677
# Epoch 460/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0676
# Epoch 461/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0675
# Epoch 462/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0672
# Epoch 463/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0671
# Epoch 464/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0669
# Epoch 465/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0667
# Epoch 466/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0666
# Epoch 467/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0663
# Epoch 468/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0662
# Epoch 469/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0660
# Epoch 470/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0659
# Epoch 471/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0657
# Epoch 472/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0655
# Epoch 473/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0653
# Epoch 474/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0652
# Epoch 475/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0650
# Epoch 476/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0648
# Epoch 477/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0647
# Epoch 478/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0645
# Epoch 479/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0643
# Epoch 480/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0642
# Epoch 481/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0640
# Epoch 482/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0638
# Epoch 483/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0637
# Epoch 484/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0636
# Epoch 485/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0634
# Epoch 486/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0632
# Epoch 487/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0631
# Epoch 488/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0629
# Epoch 489/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 490/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0626
# Epoch 491/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0624
# Epoch 492/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0622
# Epoch 493/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0621
# Epoch 494/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0619
# Epoch 495/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0618
# Epoch 496/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0617
# Epoch 497/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0615
# Epoch 498/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0613
# Epoch 499/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0611
# Epoch 500/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0610

# %%
# Hiển thị loss theo số epoch
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Sau khi đã huấn luyện, ta lưu mô hình về để sau này tái sử dụng
# Lưu ý: hai phương thức lưu mô hình `save` và tải mô hình lên 'load'
# được sử dụng khi muốn tái sử dụng nhiều lần mà KHÔNG CẦN PHẢI HUẤN LUYỆN LẠI
nn.save('neural_network_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## 5. Trực quan hóa mô hình và dự đoán với dữ liệu test

# %%
# Khởi tạo đối tượng mới và gọi phương thức load mô hình từ file
pretrain_nn = NeuralNetwork()
pretrain_nn.load('neural_network_model.h5')

# %%
# In ra bộ tham số tối ưu lớp cuối cùng
theta = pretrain_nn.get_weights(-1)
print('Tham số tối ưu: ')
print(theta)
# Out:
# Tham số tối ưu:
# [array([[ 3.49561   , -3.8867433 ,  3.5547876 , -1.85227   ],
#        [-4.05069   ,  2.566646  ,  2.9933317 , -1.6771914 ],
#        [ 1.4608077 ,  2.2615964 , -0.68739986, -2.4553926 ]],
#       dtype=float32), array([-0.7709448 , -0.95523506, -2.144563  ,  3.870745  ], dtype=float32)]

# %%
# Trực quan hóa dữ liệu và mô hình sau khi huấn luyện
# Ý tưởng: lấy mẫu dày đặc các điểm trong phạm vi dữ liệu train
# Sau đó dùng mô hình để dự đoán và hiển thị kết quả

# `colors` là các marker được sử dụng để trực quan hóa kết quả test
colors = ['r+', 'g+', 'b+', 'y+']
# `gt_colors` là các marker được sử dụng để trực quan hóa dữ liệu train
gt_colors = ['ro', 'go', 'bo', 'yo']

# Lấy mẫu dày đặc các điểm
x = np.arange(-8, 17, 1)
y = np.arange(-8, 17, 1)
xx, yy = np.meshgrid(x,y)

xx = xx.reshape(-1)
yy = yy.reshape(-1)

# Tạo các dữ liệu test dày đặc
X_test = np.concatenate([[xx],[yy]], axis=0).T
Y_pred = pretrain_nn.predict(X_test)

for i in range(len(xx)):
    plt.plot(xx[i],yy[i], colors[np.argmax(Y_pred[i])])
plt.plot(pts1[:,0], pts1[:,1], gt_colors[0])
plt.plot(pts2[:,0], pts2[:,1], gt_colors[1])
plt.plot(pts3[:,0], pts3[:,1], gt_colors[2])
plt.plot(pts4[:,0], pts4[:,1], gt_colors[3])
plt.show()
# Out:
# 20/20 [==============================] - 1s 3ms/step

# %% [markdown]
# Ta có thể thấy rằng, không gian mặt phẳng đã được phân loại sử dụng mô hình Neural Network đã huấn luyện trước đó. Dựa trên hình trên ta thấy kết quả khá chính xác, chỉ trừ một số điểm ở biên giữa các lớp.

# %% [markdown]
# ## 6. Thử nghiệm với tập dữ liệu  MNIST
#
# MNIST là tập dữ liệu chữ số viết tay kinh điển trong lĩnh vực máy học. Để tải và sử dụng dữ liệu này cực kỳ đơn giản chỉ với 2 dòng code:

# %%
# Prepare MNIST dataset
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# Để hiểu rõ hơn về dữ liệu này, ta sẽ trực quan hóa dữ liệu bằng cách hiển thị ảnh và xem kích thước ảnh.

# %%
plt.imshow(x_train[1234])
print('Nhãn của mẫu dữ liệu thứ 1234: ', y_train[1234])
print('Kích thước của ảnh train: ', x_train[1234].shape)
print('Số điểm ảnh nếu biến đổi thành vector: ',
      x_train[1234].shape[0]*x_train[1234].shape[1])
# Out:
# Nhãn của mẫu dữ liệu thứ 1234:  3
# Kích thước của ảnh train:  (28, 28)
# Số điểm ảnh nếu biến đổi thành vector:  784

# %% [markdown]
# Tiền xử lý dữ liệu trước khi huấn luyện mô hình:
# - Chuyển output sang dạng one-hot vector
# - Chuẩn hóa dữ liệu input về khoảng giá trị `[0-1]`

# %%
# Hàm chuyển đổi output từ dạng nhãn (label) sang vector one-hot
def onehot(y):
    oh = np.zeros((y.shape[0], y.max()+1))
    oh[np.arange(y.shape[0]), y] = 1
    return oh

y_train_oh = onehot(y_train)
y_test_oh = onehot(y_test)

# Chuẩn hóa dữ liệu input trên dữ liệu train và test
n_train_sample, h, w = x_train.shape
n_test_sample, _,_ = x_test.shape # Kích thước ngang x cao giống nhau trên tất cả mẫu

x_train = (x_train.astype('float32')) / 255.0
x_test = (x_test.astype('float32')) / 255.0
x_train_vec = x_train.reshape((n_train_sample, w*h))
x_test_vec = x_test.reshape((n_test_sample, w*h))

# %% [markdown]
# Khởi tạo mô hình từ đầu sao cho phù hợp với dữ liệu MNIST.
# Trong đó, thông tin cấu hình về lớp ẩn:
# - 2 lớp ẩn
# - 100 neuron mỗi lớp ẩn
# - huấn luyện với 30 epochs

# %%
nn4mnist = NeuralNetwork()

# Hoàn tất đoạn code sau đây với việc sử dụng biến `nn4mnist` để gọi
# phương thức `build`# và `train`. Lưu ý: sử dụng các tham số phù hợp
# theo yêu cầu đã nêu.

# YOUR CODE HERE
#raise NotImplementedError()
nn4mnist.build(784,10,2,100)

nn4mnist.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 784)]             0
#
#  dense_25 (Dense)            (None, 100)               78500
#
#  dense_26 (Dense)            (None, 100)               10100
#
#  dense_27 (Dense)            (None, 10)                1010
#
# =================================================================
# Total params: 89610 (350.04 KB)
# Trainable params: 89610 (350.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist = nn4mnist.train(x_train_vec,y_train_oh,epochs = 30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.2701
# Epoch 2/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4500
# Epoch 3/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3457
# Epoch 4/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3026
# Epoch 5/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2735
# Epoch 6/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2499
# Epoch 7/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2302
# Epoch 8/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2132
# Epoch 9/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1977
# Epoch 10/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1851
# Epoch 11/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1732
# Epoch 12/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1625
# Epoch 13/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1531
# Epoch 14/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1448
# Epoch 15/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1370
# Epoch 16/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1300
# Epoch 17/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1235
# Epoch 18/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1172
# Epoch 19/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1118
# Epoch 20/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1064
# Epoch 21/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1016
# Epoch 22/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0972
# Epoch 23/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0930
# Epoch 24/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0892
# Epoch 25/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0857
# Epoch 26/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0820
# Epoch 27/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0789
# Epoch 28/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0759
# Epoch 29/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0730
# Epoch 30/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0703

# %%
# Trực quan hóa giá trị loss trong quá trình huấn luyện
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Kiểm tra sơ bộ biến `hist`: nếu quá trình khởi tạo và huấn luyện thành công
# thì các bài test sau sẽ vượt qua được.
assert hist is not None
assert 'loss' in hist.history
assert len(hist.history['loss']) == 30

# %%
# Kiểm tra với bộ test
assert len(nn4mnist.model.layers)==4
assert str(type(nn4mnist.model.layers[0])).endswith("input_layer.InputLayer'>") == True
assert str(type(nn4mnist.model.layers[1])).endswith("core.dense.Dense'>") == True
assert str(type(nn4mnist.model.layers[2])).endswith("core.dense.Dense'>") == True
assert str(type(nn4mnist.model.layers[3])).endswith("core.dense.Dense'>") == True

# Check shapes
assert nn4mnist.model.layers[0].input_shape[0][1] == 784
assert nn4mnist.model.layers[1].output_shape[1] == 100
assert nn4mnist.model.layers[2].output_shape[1] == 100
assert nn4mnist.model.layers[3].output_shape[1] == 10

# Check activation
assert abs(nn4mnist.model.layers[1].activation(1.0).numpy() - 0.7310586)<0.00000001
assert abs(nn4mnist.model.layers[2].activation(-1.0).numpy() - 0.26894143)<0.00000001

inputs = tf.random.normal(shape=(32, 10))
assert np.mean(abs(nn4mnist.model.layers[3].activation(inputs).numpy() -
                   tf.keras.activations.softmax(inputs).numpy()))<0.00001

# Check bias
assert nn4mnist.model.layers[1].use_bias == True
assert nn4mnist.model.layers[2].use_bias == True
assert nn4mnist.model.layers[3].use_bias == True

# %% [markdown]
# Sau quá trình huấn luyện, chúng ta sử dụng mô hình để dự đoán trên mẫu dữ liệu test:

# %%
pred = nn4mnist.predict(x_test_vec)
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# Cuối cùng, trực quan hóa một mẫu dữ liệu test bất kỳ (ví dụ mẫu thứ 50):

# %%
# Show the 50-th test sample
test_id = 50
plt.imshow(x_test[test_id])
print('Label of the data: ', y_test[test_id])
print('Predicted label of the data: ', np.argmax(pred[test_id]))
# Out:
# Label of the data:  6
# Predicted label of the data:  6
