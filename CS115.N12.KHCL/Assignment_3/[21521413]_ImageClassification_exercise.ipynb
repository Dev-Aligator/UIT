# %% [markdown]
# ### Inport necessary packages

# %%
import torch
from torch.utils.data import DataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
import matplotlib.pyplot as plt

# %%
import random
import numpy as np

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
import os
import cv2

# %%
seed = 21521413

# %%
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Load Folio Leaf Dataset

# %%
root_dir = '/home/aligator/Aligator/UIT/CS115.N12.KHCL/Assignment_3/Folio Leaf Dataset'

# %%
list_folders = os.listdir(root_dir)
list_folders
# Out:
# ['vieux garcon',
#  'guava',
#  'sweet olive',
#  'thevetia',
#  'sweet potato',
#  'bitter orange',
#  'barbados cherry',
#  'hibiscus',
#  'papaya',
#  'star apple',
#  'lychee',
#  'chrysanthemum',
#  'geranium',
#  'eggplant',
#  'pomme jacquot',
#  'coeur demoiselle',
#  'fruitcitere',
#  'beaumier du perou',
#  'ketembilla',
#  'betel',
#  'jackfruit',
#  'caricature plant',
#  'duranta gold',
#  'ashanti blood',
#  'croton',
#  'chocolate tree',
#  'ficus',
#  'coffee',
#  'mulberry leaf',
#  'pimento',
#  'chinese guava',
#  'rose']

# %%
def resize(image):
    return cv2.resize(image, (232, 412))

# %% [markdown]
# ### Process the raw data

# %%
# Create dataset (X, y)
X, y = [], []
for folder in list_folders:
  list_image_paths = os.listdir(root_dir + '/' + folder)
  for image_path in list_image_paths:
    img_matrix = resize(cv2.imread(root_dir + '/' + folder + '/' + image_path, 0))
    X.append([img_matrix])
    y.append(folder)

# %%
# Task: Normalize the value of each pixel by dividing them to 255
X = np.array(X)/255

# %%
# Task: Perform 'label encoding' on y
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %% [markdown]
# ### Create the train/test set

# %%
# Task: Split dataset into training and testing set (7:3, random_seed = Your Student ID)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state=21521413)

# %%
X_train, X_test = np.array(X_train), np.array(X_test)
y_train, y_test = np.array(y_train), np.array(y_test)

# %%
# Task: Convert the data type of X_train, X_test, y_train, y_test to 'Tensor'
X_train = torch.from_numpy(X_train).float()
X_test = torch.from_numpy(X_test).float()
y_train = torch.from_numpy(y_train)
y_test = torch.from_numpy(y_test)

# %%
# Task: Create train_dataset, test_dataset
from torch.utils.data import TensorDataset
train_dataset= TensorDataset(X_train, y_train)
test_dataset = TensorDataset(X_test, y_test)

# %%
# Task: Create train_loader (batch_size = 64), test_loader

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset)

# %% [markdown]
# ### Implement Classifiers

# %%
# Task: Implement "Logistic Regression" model with PyTorch
import torch.nn as nn
import torch.nn.functional as F

class LogisticRegression(nn.Module):
    # input_dim -> the number of independent variables (attributes)
    # output_dim -> the number of (unique) classes for classification (e.g., dog-cat -> 2; car-bicycle-plane -> 3)
    def __init__(self, input_dim, output_dim):  
        super().__init__()
        self.linear = nn.Linear(input_dim, output_dim)
        
    def forward(self, x):
        logits = self.linear(x)
        probs = F.softmax(logits, dim=1)
        return logits, probs

# %%
import torch.optim as optim

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
# Task: Design the 'train_model' function for training models
# Loss Function: Cross Entropy Loss
# Optimizer: Adam -> optim.Adam(model.parameters(), lr=...)
def train_model(data_loader, model, init_lr, maxEpoch):
    # Loss Function
    criterion = nn.CrossEntropyLoss()

    # Optimization Algorithm.
    # We can use other optimizers such as ADAM, RMSprop, etc.
    optimizer = optim.SGD(model.parameters(), lr=init_lr)
    
    loss_each_epoch = []  # For tracking the trend of loss value
    
    # Switch model to the training mode
    model.train()

    for epoch in range(maxEpoch):
        sum_loss = 0.0
        for (imgs, labels) in data_loader:
            # Load data to GPU/CPU
            imgs, labels = imgs.to(device), labels.to(device)

            # Change to the correct tensor shape
            # Our data currently is in the format (batch_size, color_channel, w, h) (64, 1, 28, 28)
            # We need to change our data to (batch_size, color_channel * w * h) (64, 1 * 28 * 28)
            imgs = imgs.reshape(imgs.shape[0], -1)

            # forward pass
            logits, _ = model(imgs)  # Feed the training data into the model
            loss = criterion(logits, labels)  # Calculate the loss value

            # backward pass
            optimizer.zero_grad()  # Empty the optimizer
            loss.backward()  # Compute the gradient dJ/dw's

            optimizer.step()  # Update the model's parameters

            sum_loss += loss.item()
        loss_each_epoch.append(sum_loss/len(data_loader.dataset))
        print(f'Epoch {epoch + 1}/{maxEpoch}, Loss: {loss_each_epoch[-1]:.2f}')
    return loss_each_epoch

# %%
# Task: Design the 'model_evaluation' function for evaluating the trained models
def model_evaluation(data_loader, model):
    nCorrects = 0
    model.eval()  # put our model on the evaluation mode

    with torch.no_grad():
        for (imgs, labels) in data_loader:
            imgs, labels = imgs.to(device), labels.to(device)
            imgs = imgs.reshape(imgs.shape[0], -1)

            # forward
            _, probs = model(imgs)
            _, y_pred = probs.max(1)
            nCorrects += (y_pred == labels).sum()
    print(f'We got {nCorrects.item()}/{len(data_loader.dataset)} correct. Accuracy = {nCorrects.item()/len(data_loader.dataset) * 100:.2f}%')

# %%
# Train Logistic Regression model
# Input dim = 412 * 232
# Output dim = 32
# Initial Learning Rate: 0.001
# Max Epoch = 600

clf_LR = LogisticRegression(input_dim=412 * 232, output_dim=32).to(device)
loss_each_epoch_LR = train_model(data_loader=train_loader, model=clf_LR, init_lr=0.001, maxEpoch=600)
# Out:
# Epoch 1/600, Loss: 0.07
# Epoch 2/600, Loss: 0.08
# Epoch 3/600, Loss: 0.08
# Epoch 4/600, Loss: 0.10
# Epoch 5/600, Loss: 0.10
# Epoch 6/600, Loss: 0.08
# Epoch 7/600, Loss: 0.06
# Epoch 8/600, Loss: 0.06
# Epoch 9/600, Loss: 0.06
# Epoch 10/600, Loss: 0.06
# Epoch 11/600, Loss: 0.06
# Epoch 12/600, Loss: 0.05
# Epoch 13/600, Loss: 0.05
# Epoch 14/600, Loss: 0.05
# Epoch 15/600, Loss: 0.05
# Epoch 16/600, Loss: 0.04
# Epoch 17/600, Loss: 0.05
# Epoch 582/600, Loss: 0.00
# Epoch 583/600, Loss: 0.00
# Epoch 584/600, Loss: 0.00
# Epoch 585/600, Loss: 0.00
# Epoch 586/600, Loss: 0.00
# Epoch 587/600, Loss: 0.00
# Epoch 588/600, Loss: 0.00
# Epoch 589/600, Loss: 0.00
# Epoch 590/600, Loss: 0.00
# Epoch 591/600, Loss: 0.00
# Epoch 592/600, Loss: 0.00
# Epoch 593/600, Loss: 0.00
# Epoch 594/600, Loss: 0.00
# Epoch 595/600, Loss: 0.00
# Epoch 596/600, Loss: 0.00
# Epoch 597/600, Loss: 0.00
# Epoch 598/600, Loss: 0.00
# Epoch 599/600, Loss: 0.00
# Epoch 600/600, Loss: 0.00

# %%
plt.plot(range(1, len(loss_each_epoch_LR) + 1), loss_each_epoch_LR)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('LogisticRegression')
# Out:
# Text(0.5, 1.0, 'LogisticRegression')

# %%
print('Logistic Regression (Train Accuracy)')
model_evaluation(data_loader=train_loader, model=clf_LR)
# Out:
# Logistic Regression (Train Accuracy)
# We got 445/445 correct. Accuracy = 100.00%

# %%
print('Logistic Regression (Test Accuracy)')
model_evaluation(data_loader=test_loader, model=clf_LR)
# Out:
# Logistic Regression (Test Accuracy)
# We got 144/192 correct. Accuracy = 75.00%

# %%
ROW_IMG, N_ROWS = 3, 2

fig = plt.figure()
for index in range(1, ROW_IMG * N_ROWS + 1):
    plt.subplot(N_ROWS, ROW_IMG, index)
    plt.axis('off')
    plt.imshow(test_dataset[index][0].squeeze(), cmap='gray_r')
    
    with torch.no_grad():
        clf_LR.eval()
        X = test_dataset[index][0].reshape(test_dataset[index][0].shape[0], -1).to(device)
        _, probs = clf_LR(X)
    title = f'Predict: {le.inverse_transform([torch.argmax(probs).item()])[0]} ({torch.max(probs * 100):.0f}%)\n True Label: {le.inverse_transform([test_dataset[index][-1]])[0]}'
    
    plt.title(title, fontsize=7)
plt.show()

# %%
# Task: Build a MLP model with 6 layers (input layer, ouput layer and 4 hidden layers)
# The activation of each node in 'input' layer and 'hidden' layers is ReLU
# Information about each layer:
# + Input layer: (input_dim, 2048)
# + Hidden layer 1: (2048, 1024)
# + Hidden layer 2: (1024, 1024)
# + Hidden layer 3: (1024, 512)
# + Hidden layer 4: (512, 512)
# + Output layer: (512, output_dim)

class MLP(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.classifier = nn.Sequential(
            nn.Linear(input_dim, 2048),
            nn.ReLU(),
            nn.Linear(2048, 1024),
            nn.ReLU(),
            nn.Linear(1024, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, output_dim)
        )

    def forward(self, x):
        logits = self.classifier(x)
        probs = F.softmax(logits, dim=1)
        return logits, probs

# %%
clf_MLP = MLP(input_dim=412 * 232, output_dim=32).to(device)
clf_MLP
# Out:
# MLP(
#   (classifier): Sequential(
#     (0): Linear(in_features=95584, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=2048, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=1024, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=1024, out_features=512, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=512, out_features=512, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=512, out_features=32, bias=True)
#   )
# )

# %%
# Train MLP model
# Input dim = 412 * 233
# Output dim = 32
# Initial Learning Rate: 0.001
# Max Epoch = 600
loss_each_epoch_MLP = train_model(train_loader, clf_MLP, 0.001, 600)
# Out:
# Epoch 1/600, Loss: 0.05
# Epoch 2/600, Loss: 0.05
# Epoch 3/600, Loss: 0.05
# Epoch 4/600, Loss: 0.05
# Epoch 5/600, Loss: 0.05
# Epoch 6/600, Loss: 0.05
# Epoch 7/600, Loss: 0.05
# Epoch 8/600, Loss: 0.05
# Epoch 9/600, Loss: 0.05
# Epoch 10/600, Loss: 0.05
# Epoch 11/600, Loss: 0.05
# Epoch 12/600, Loss: 0.05
# Epoch 13/600, Loss: 0.05
# Epoch 14/600, Loss: 0.05
# Epoch 15/600, Loss: 0.05
# Epoch 16/600, Loss: 0.05
# Epoch 17/600, Loss: 0.05
# Epoch 18/600, Loss: 0.05
# Epoch 19/600, Loss: 0.05
# Epoch 20/600, Loss: 0.05
# Epoch 21/600, Loss: 0.05
# Epoch 22/600, Loss: 0.05
# Epoch 23/600, Loss: 0.05
# Epoch 24/600, Loss: 0.05
# Epoch 25/600, Loss: 0.05
# Epoch 26/600, Loss: 0.05
# Epoch 27/600, Loss: 0.05
# Epoch 28/600, Loss: 0.05
# Epoch 29/600, Loss: 0.05
# Epoch 30/600, Loss: 0.05
# Epoch 31/600, Loss: 0.05
# Epoch 32/600, Loss: 0.05
# Epoch 33/600, Loss: 0.05
# Epoch 34/600, Loss: 0.05
# Epoch 35/600, Loss: 0.05
# Epoch 36/600, Loss: 0.05
# Epoch 37/600, Loss: 0.05
# Epoch 38/600, Loss: 0.05
# Epoch 39/600, Loss: 0.05
# Epoch 40/600, Loss: 0.05
# Epoch 41/600, Loss: 0.05
# Epoch 42/600, Loss: 0.05
# Epoch 43/600, Loss: 0.05
# Epoch 44/600, Loss: 0.05
# Epoch 45/600, Loss: 0.05
# Epoch 46/600, Loss: 0.05
# Epoch 47/600, Loss: 0.05
# Epoch 48/600, Loss: 0.05
# Epoch 49/600, Loss: 0.05
# Epoch 50/600, Loss: 0.05
# Epoch 51/600, Loss: 0.05
# Epoch 52/600, Loss: 0.05
# Epoch 53/600, Loss: 0.05
# Epoch 54/600, Loss: 0.05
# Epoch 55/600, Loss: 0.05
# Epoch 56/600, Loss: 0.05
# Epoch 57/600, Loss: 0.05
# Epoch 58/600, Loss: 0.05
# Epoch 59/600, Loss: 0.05
# Epoch 60/600, Loss: 0.05
# Epoch 61/600, Loss: 0.05
# Epoch 62/600, Loss: 0.05
# Epoch 63/600, Loss: 0.05
# Epoch 64/600, Loss: 0.05
# Epoch 65/600, Loss: 0.05
# Epoch 66/600, Loss: 0.05
# Epoch 67/600, Loss: 0.05
# Epoch 68/600, Loss: 0.05
# Epoch 69/600, Loss: 0.05
# Epoch 70/600, Loss: 0.05
# Epoch 71/600, Loss: 0.05
# Epoch 72/600, Loss: 0.05
# Epoch 73/600, Loss: 0.05
# Epoch 74/600, Loss: 0.05
# Epoch 75/600, Loss: 0.05
# Epoch 76/600, Loss: 0.05
# Epoch 77/600, Loss: 0.05
# Epoch 78/600, Loss: 0.05
# Epoch 79/600, Loss: 0.05
# Epoch 80/600, Loss: 0.05
# Epoch 81/600, Loss: 0.05
# Epoch 82/600, Loss: 0.05
# Epoch 83/600, Loss: 0.05
# Epoch 84/600, Loss: 0.05
# Epoch 85/600, Loss: 0.05
# Epoch 86/600, Loss: 0.05
# Epoch 87/600, Loss: 0.05
# Epoch 88/600, Loss: 0.05
# Epoch 89/600, Loss: 0.05
# Epoch 90/600, Loss: 0.05
# Epoch 91/600, Loss: 0.05
# Epoch 92/600, Loss: 0.05
# Epoch 93/600, Loss: 0.05
# Epoch 94/600, Loss: 0.05
# Epoch 95/600, Loss: 0.05
# Epoch 96/600, Loss: 0.05
# Epoch 97/600, Loss: 0.05
# Epoch 98/600, Loss: 0.05
# Epoch 99/600, Loss: 0.05
# Epoch 100/600, Loss: 0.05
# Epoch 101/600, Loss: 0.05
# Epoch 102/600, Loss: 0.05
# Epoch 103/600, Loss: 0.05
# Epoch 104/600, Loss: 0.05
# Epoch 105/600, Loss: 0.05
# Epoch 106/600, Loss: 0.05
# Epoch 107/600, Loss: 0.05
# Epoch 108/600, Loss: 0.05
# Epoch 109/600, Loss: 0.05
# Epoch 110/600, Loss: 0.05
# Epoch 111/600, Loss: 0.05
# Epoch 112/600, Loss: 0.05
# Epoch 113/600, Loss: 0.05
# Epoch 114/600, Loss: 0.05
# Epoch 115/600, Loss: 0.05
# Epoch 116/600, Loss: 0.05
# Epoch 117/600, Loss: 0.05
# Epoch 118/600, Loss: 0.05
# Epoch 119/600, Loss: 0.05
# Epoch 120/600, Loss: 0.05
# Epoch 121/600, Loss: 0.05
# Epoch 122/600, Loss: 0.05
# Epoch 123/600, Loss: 0.05
# Epoch 124/600, Loss: 0.05
# Epoch 125/600, Loss: 0.05
# Epoch 126/600, Loss: 0.05
# Epoch 127/600, Loss: 0.05
# Epoch 128/600, Loss: 0.05
# Epoch 129/600, Loss: 0.05
# Epoch 130/600, Loss: 0.05
# Epoch 131/600, Loss: 0.05
# Epoch 132/600, Loss: 0.05
# Epoch 133/600, Loss: 0.05
# Epoch 134/600, Loss: 0.05
# Epoch 135/600, Loss: 0.05
# Epoch 136/600, Loss: 0.05
# Epoch 137/600, Loss: 0.05
# Epoch 138/600, Loss: 0.05
# Epoch 139/600, Loss: 0.05
# Epoch 140/600, Loss: 0.05
# Epoch 141/600, Loss: 0.05
# Epoch 142/600, Loss: 0.05
# Epoch 143/600, Loss: 0.05
# Epoch 144/600, Loss: 0.05
# Epoch 145/600, Loss: 0.05
# Epoch 146/600, Loss: 0.05
# Epoch 147/600, Loss: 0.05
# Epoch 148/600, Loss: 0.05
# Epoch 149/600, Loss: 0.05
# Epoch 150/600, Loss: 0.05
# Epoch 151/600, Loss: 0.05
# Epoch 152/600, Loss: 0.05
# Epoch 153/600, Loss: 0.05
# Epoch 154/600, Loss: 0.05
# Epoch 155/600, Loss: 0.05
# Epoch 156/600, Loss: 0.05
# Epoch 157/600, Loss: 0.05
# Epoch 158/600, Loss: 0.05
# Epoch 159/600, Loss: 0.05
# Epoch 160/600, Loss: 0.05
# Epoch 161/600, Loss: 0.05
# Epoch 162/600, Loss: 0.05
# Epoch 163/600, Loss: 0.05
# Epoch 164/600, Loss: 0.05
# Epoch 165/600, Loss: 0.05
# Epoch 166/600, Loss: 0.05
# Epoch 167/600, Loss: 0.05
# Epoch 168/600, Loss: 0.05
# Epoch 169/600, Loss: 0.05
# Epoch 170/600, Loss: 0.05
# Epoch 171/600, Loss: 0.05
# Epoch 172/600, Loss: 0.05
# Epoch 173/600, Loss: 0.05
# Epoch 174/600, Loss: 0.05
# Epoch 175/600, Loss: 0.05
# Epoch 176/600, Loss: 0.05
# Epoch 177/600, Loss: 0.05
# Epoch 178/600, Loss: 0.05
# Epoch 179/600, Loss: 0.05
# Epoch 180/600, Loss: 0.05
# Epoch 181/600, Loss: 0.05
# Epoch 182/600, Loss: 0.05
# Epoch 183/600, Loss: 0.05
# Epoch 184/600, Loss: 0.05
# Epoch 185/600, Loss: 0.05
# Epoch 186/600, Loss: 0.05
# Epoch 187/600, Loss: 0.05
# Epoch 188/600, Loss: 0.05
# Epoch 189/600, Loss: 0.05
# Epoch 190/600, Loss: 0.05
# Epoch 191/600, Loss: 0.05
# Epoch 192/600, Loss: 0.05
# Epoch 193/600, Loss: 0.05
# Epoch 194/600, Loss: 0.05
# Epoch 195/600, Loss: 0.05
# Epoch 196/600, Loss: 0.05
# Epoch 197/600, Loss: 0.05
# Epoch 198/600, Loss: 0.05
# Epoch 199/600, Loss: 0.05
# Epoch 200/600, Loss: 0.05
# Epoch 201/600, Loss: 0.05
# Epoch 202/600, Loss: 0.05
# Epoch 203/600, Loss: 0.05
# Epoch 204/600, Loss: 0.05
# Epoch 205/600, Loss: 0.05
# Epoch 206/600, Loss: 0.05
# Epoch 207/600, Loss: 0.05
# Epoch 208/600, Loss: 0.05
# Epoch 209/600, Loss: 0.05
# Epoch 210/600, Loss: 0.05
# Epoch 211/600, Loss: 0.05
# Epoch 212/600, Loss: 0.05
# Epoch 213/600, Loss: 0.05
# Epoch 214/600, Loss: 0.05
# Epoch 215/600, Loss: 0.05
# Epoch 216/600, Loss: 0.05
# Epoch 217/600, Loss: 0.05
# Epoch 218/600, Loss: 0.05
# Epoch 219/600, Loss: 0.05
# Epoch 220/600, Loss: 0.05
# Epoch 221/600, Loss: 0.05
# Epoch 222/600, Loss: 0.05
# Epoch 223/600, Loss: 0.05
# Epoch 224/600, Loss: 0.05
# Epoch 225/600, Loss: 0.05
# Epoch 226/600, Loss: 0.05
# Epoch 227/600, Loss: 0.05
# Epoch 228/600, Loss: 0.05
# Epoch 229/600, Loss: 0.05
# Epoch 230/600, Loss: 0.05
# Epoch 231/600, Loss: 0.05
# Epoch 232/600, Loss: 0.05
# Epoch 233/600, Loss: 0.05
# Epoch 234/600, Loss: 0.05
# Epoch 235/600, Loss: 0.05
# Epoch 236/600, Loss: 0.05
# Epoch 237/600, Loss: 0.05
# Epoch 238/600, Loss: 0.05
# Epoch 239/600, Loss: 0.05
# Epoch 240/600, Loss: 0.05
# Epoch 241/600, Loss: 0.05
# Epoch 242/600, Loss: 0.05
# Epoch 243/600, Loss: 0.05
# Epoch 244/600, Loss: 0.05
# Epoch 245/600, Loss: 0.05
# Epoch 246/600, Loss: 0.05
# Epoch 247/600, Loss: 0.05
# Epoch 248/600, Loss: 0.05
# Epoch 249/600, Loss: 0.05
# Epoch 250/600, Loss: 0.05
# Epoch 251/600, Loss: 0.05
# Epoch 252/600, Loss: 0.05
# Epoch 253/600, Loss: 0.05
# Epoch 254/600, Loss: 0.05
# Epoch 255/600, Loss: 0.05
# Epoch 256/600, Loss: 0.05
# Epoch 257/600, Loss: 0.05
# Epoch 258/600, Loss: 0.05
# Epoch 259/600, Loss: 0.05
# Epoch 260/600, Loss: 0.05
# Epoch 261/600, Loss: 0.05
# Epoch 262/600, Loss: 0.05
# Epoch 263/600, Loss: 0.05
# Epoch 264/600, Loss: 0.05
# Epoch 265/600, Loss: 0.05
# Epoch 266/600, Loss: 0.05
# Epoch 267/600, Loss: 0.05
# Epoch 268/600, Loss: 0.05
# Epoch 269/600, Loss: 0.05
# Epoch 270/600, Loss: 0.05
# Epoch 271/600, Loss: 0.05
# Epoch 272/600, Loss: 0.05
# Epoch 273/600, Loss: 0.05
# Epoch 274/600, Loss: 0.05
# Epoch 275/600, Loss: 0.05
# Epoch 276/600, Loss: 0.05
# Epoch 277/600, Loss: 0.05
# Epoch 278/600, Loss: 0.05
# Epoch 279/600, Loss: 0.05
# Epoch 280/600, Loss: 0.05
# Epoch 281/600, Loss: 0.05
# Epoch 282/600, Loss: 0.05
# Epoch 283/600, Loss: 0.05
# Epoch 284/600, Loss: 0.05
# Epoch 285/600, Loss: 0.05
# Epoch 286/600, Loss: 0.05
# Epoch 287/600, Loss: 0.05
# Epoch 288/600, Loss: 0.05
# Epoch 289/600, Loss: 0.05
# Epoch 290/600, Loss: 0.05
# Epoch 291/600, Loss: 0.05
# Epoch 292/600, Loss: 0.05
# Epoch 293/600, Loss: 0.05
# Epoch 294/600, Loss: 0.05
# Epoch 295/600, Loss: 0.05
# Epoch 296/600, Loss: 0.05
# Epoch 297/600, Loss: 0.05
# Epoch 298/600, Loss: 0.05
# Epoch 299/600, Loss: 0.05
# Epoch 300/600, Loss: 0.05
# Epoch 301/600, Loss: 0.05
# Epoch 302/600, Loss: 0.05
# Epoch 303/600, Loss: 0.05
# Epoch 304/600, Loss: 0.05
# Epoch 305/600, Loss: 0.05
# Epoch 306/600, Loss: 0.05
# Epoch 307/600, Loss: 0.05
# Epoch 308/600, Loss: 0.05
# Epoch 309/600, Loss: 0.05
# Epoch 310/600, Loss: 0.05
# Epoch 311/600, Loss: 0.05
# Epoch 312/600, Loss: 0.05
# Epoch 313/600, Loss: 0.05
# Epoch 314/600, Loss: 0.05
# Epoch 315/600, Loss: 0.05
# Epoch 316/600, Loss: 0.05
# Epoch 317/600, Loss: 0.05
# Epoch 318/600, Loss: 0.05
# Epoch 319/600, Loss: 0.05
# Epoch 320/600, Loss: 0.05
# Epoch 321/600, Loss: 0.05
# Epoch 322/600, Loss: 0.05
# Epoch 323/600, Loss: 0.05
# Epoch 324/600, Loss: 0.05
# Epoch 325/600, Loss: 0.05
# Epoch 326/600, Loss: 0.05
# Epoch 327/600, Loss: 0.05
# Epoch 328/600, Loss: 0.05
# Epoch 329/600, Loss: 0.05
# Epoch 330/600, Loss: 0.05
# Epoch 331/600, Loss: 0.05
# Epoch 332/600, Loss: 0.05
# Epoch 333/600, Loss: 0.05
# Epoch 334/600, Loss: 0.05
# Epoch 335/600, Loss: 0.05
# Epoch 336/600, Loss: 0.05
# Epoch 337/600, Loss: 0.05
# Epoch 338/600, Loss: 0.05
# Epoch 339/600, Loss: 0.05
# Epoch 340/600, Loss: 0.05
# Epoch 341/600, Loss: 0.05
# Epoch 342/600, Loss: 0.05
# Epoch 343/600, Loss: 0.05
# Epoch 344/600, Loss: 0.05
# Epoch 345/600, Loss: 0.05
# Epoch 346/600, Loss: 0.05
# Epoch 347/600, Loss: 0.05
# Epoch 348/600, Loss: 0.05
# Epoch 349/600, Loss: 0.05
# Epoch 350/600, Loss: 0.05
# Epoch 351/600, Loss: 0.05
# Epoch 352/600, Loss: 0.05
# Epoch 353/600, Loss: 0.05
# Epoch 354/600, Loss: 0.05
# Epoch 355/600, Loss: 0.05
# Epoch 356/600, Loss: 0.05
# Epoch 357/600, Loss: 0.05
# Epoch 358/600, Loss: 0.05
# Epoch 359/600, Loss: 0.05
# Epoch 360/600, Loss: 0.05
# Epoch 361/600, Loss: 0.05
# Epoch 362/600, Loss: 0.05
# Epoch 363/600, Loss: 0.05
# Epoch 364/600, Loss: 0.05
# Epoch 365/600, Loss: 0.05
# Epoch 366/600, Loss: 0.05
# Epoch 367/600, Loss: 0.05
# Epoch 368/600, Loss: 0.05
# Epoch 369/600, Loss: 0.05
# Epoch 370/600, Loss: 0.05
# Epoch 371/600, Loss: 0.05
# Epoch 372/600, Loss: 0.05
# Epoch 373/600, Loss: 0.05
# Epoch 374/600, Loss: 0.05
# Epoch 375/600, Loss: 0.05
# Epoch 376/600, Loss: 0.05
# Epoch 377/600, Loss: 0.05
# Epoch 378/600, Loss: 0.05
# Epoch 379/600, Loss: 0.05
# Epoch 380/600, Loss: 0.05
# Epoch 381/600, Loss: 0.05
# Epoch 382/600, Loss: 0.05
# Epoch 383/600, Loss: 0.05
# Epoch 384/600, Loss: 0.05
# Epoch 385/600, Loss: 0.05
# Epoch 386/600, Loss: 0.05
# Epoch 387/600, Loss: 0.05
# Epoch 388/600, Loss: 0.05
# Epoch 389/600, Loss: 0.05
# Epoch 390/600, Loss: 0.05
# Epoch 391/600, Loss: 0.05
# Epoch 392/600, Loss: 0.05
# Epoch 393/600, Loss: 0.05
# Epoch 394/600, Loss: 0.05
# Epoch 395/600, Loss: 0.05
# Epoch 396/600, Loss: 0.05
# Epoch 397/600, Loss: 0.05
# Epoch 398/600, Loss: 0.05
# Epoch 399/600, Loss: 0.05
# Epoch 400/600, Loss: 0.05
# Epoch 401/600, Loss: 0.05
# Epoch 402/600, Loss: 0.05
# Epoch 403/600, Loss: 0.05
# Epoch 404/600, Loss: 0.05
# Epoch 405/600, Loss: 0.05
# Epoch 406/600, Loss: 0.05
# Epoch 407/600, Loss: 0.05
# Epoch 408/600, Loss: 0.05
# Epoch 409/600, Loss: 0.05
# Epoch 410/600, Loss: 0.05
# Epoch 411/600, Loss: 0.05
# Epoch 412/600, Loss: 0.05
# Epoch 413/600, Loss: 0.05
# Epoch 414/600, Loss: 0.05
# Epoch 415/600, Loss: 0.05
# Epoch 416/600, Loss: 0.05
# Epoch 417/600, Loss: 0.05
# Epoch 418/600, Loss: 0.05
# Epoch 419/600, Loss: 0.05
# Epoch 420/600, Loss: 0.05
# Epoch 421/600, Loss: 0.05
# Epoch 422/600, Loss: 0.05
# Epoch 423/600, Loss: 0.05
# Epoch 424/600, Loss: 0.05
# Epoch 425/600, Loss: 0.05
# Epoch 426/600, Loss: 0.05
# Epoch 427/600, Loss: 0.05
# Epoch 428/600, Loss: 0.05
# Epoch 429/600, Loss: 0.05
# Epoch 430/600, Loss: 0.05
# Epoch 431/600, Loss: 0.05
# Epoch 432/600, Loss: 0.05
# Epoch 433/600, Loss: 0.05
# Epoch 434/600, Loss: 0.05
# Epoch 435/600, Loss: 0.05
# Epoch 436/600, Loss: 0.05
# Epoch 437/600, Loss: 0.05
# Epoch 438/600, Loss: 0.05
# Epoch 439/600, Loss: 0.05
# Epoch 440/600, Loss: 0.05
# Epoch 441/600, Loss: 0.05
# Epoch 442/600, Loss: 0.05
# Epoch 443/600, Loss: 0.05
# Epoch 444/600, Loss: 0.05
# Epoch 445/600, Loss: 0.05
# Epoch 446/600, Loss: 0.05
# Epoch 447/600, Loss: 0.05
# Epoch 448/600, Loss: 0.05
# Epoch 449/600, Loss: 0.05
# Epoch 450/600, Loss: 0.05
# Epoch 451/600, Loss: 0.05
# Epoch 452/600, Loss: 0.05
# Epoch 453/600, Loss: 0.05
# Epoch 454/600, Loss: 0.05
# Epoch 455/600, Loss: 0.05
# Epoch 456/600, Loss: 0.05
# Epoch 457/600, Loss: 0.05
# Epoch 458/600, Loss: 0.05
# Epoch 459/600, Loss: 0.05
# Epoch 460/600, Loss: 0.05
# Epoch 461/600, Loss: 0.05
# Epoch 462/600, Loss: 0.05
# Epoch 463/600, Loss: 0.05
# Epoch 464/600, Loss: 0.05
# Epoch 465/600, Loss: 0.05
# Epoch 466/600, Loss: 0.05
# Epoch 467/600, Loss: 0.05
# Epoch 468/600, Loss: 0.05
# Epoch 469/600, Loss: 0.05
# Epoch 470/600, Loss: 0.05
# Epoch 471/600, Loss: 0.05
# Epoch 472/600, Loss: 0.05
# Epoch 473/600, Loss: 0.05
# Epoch 474/600, Loss: 0.05
# Epoch 475/600, Loss: 0.05
# Epoch 476/600, Loss: 0.05
# Epoch 477/600, Loss: 0.05
# Epoch 478/600, Loss: 0.05
# Epoch 479/600, Loss: 0.05
# Epoch 480/600, Loss: 0.05
# Epoch 481/600, Loss: 0.05
# Epoch 482/600, Loss: 0.05
# Epoch 483/600, Loss: 0.05
# Epoch 484/600, Loss: 0.05
# Epoch 485/600, Loss: 0.05
# Epoch 486/600, Loss: 0.05
# Epoch 487/600, Loss: 0.05
# Epoch 488/600, Loss: 0.05
# Epoch 489/600, Loss: 0.05
# Epoch 490/600, Loss: 0.05
# Epoch 491/600, Loss: 0.05
# Epoch 492/600, Loss: 0.05
# Epoch 493/600, Loss: 0.05
# Epoch 494/600, Loss: 0.05
# Epoch 495/600, Loss: 0.05
# Epoch 496/600, Loss: 0.05
# Epoch 497/600, Loss: 0.05
# Epoch 498/600, Loss: 0.05
# Epoch 499/600, Loss: 0.05
# Epoch 500/600, Loss: 0.05
# Epoch 501/600, Loss: 0.05
# Epoch 502/600, Loss: 0.05
# Epoch 503/600, Loss: 0.05
# Epoch 504/600, Loss: 0.05
# Epoch 505/600, Loss: 0.05
# Epoch 506/600, Loss: 0.05
# Epoch 507/600, Loss: 0.05
# Epoch 508/600, Loss: 0.05
# Epoch 509/600, Loss: 0.05
# Epoch 510/600, Loss: 0.05
# Epoch 511/600, Loss: 0.05
# Epoch 512/600, Loss: 0.05
# Epoch 513/600, Loss: 0.05
# Epoch 514/600, Loss: 0.05
# Epoch 515/600, Loss: 0.05
# Epoch 516/600, Loss: 0.05
# Epoch 517/600, Loss: 0.05
# Epoch 518/600, Loss: 0.05
# Epoch 519/600, Loss: 0.05
# Epoch 520/600, Loss: 0.05
# Epoch 521/600, Loss: 0.05
# Epoch 522/600, Loss: 0.05
# Epoch 523/600, Loss: 0.05
# Epoch 524/600, Loss: 0.05
# Epoch 525/600, Loss: 0.05
# Epoch 526/600, Loss: 0.05
# Epoch 527/600, Loss: 0.05
# Epoch 528/600, Loss: 0.05
# Epoch 529/600, Loss: 0.05
# Epoch 530/600, Loss: 0.05
# Epoch 531/600, Loss: 0.05
# Epoch 532/600, Loss: 0.05
# Epoch 533/600, Loss: 0.05
# Epoch 534/600, Loss: 0.05
# Epoch 535/600, Loss: 0.05
# Epoch 536/600, Loss: 0.05
# Epoch 537/600, Loss: 0.05
# Epoch 538/600, Loss: 0.05
# Epoch 539/600, Loss: 0.05
# Epoch 540/600, Loss: 0.05
# Epoch 541/600, Loss: 0.05
# Epoch 542/600, Loss: 0.05
# Epoch 543/600, Loss: 0.05
# Epoch 544/600, Loss: 0.05
# Epoch 545/600, Loss: 0.05
# Epoch 546/600, Loss: 0.05
# Epoch 547/600, Loss: 0.05
# Epoch 548/600, Loss: 0.05
# Epoch 549/600, Loss: 0.05
# Epoch 550/600, Loss: 0.05
# Epoch 551/600, Loss: 0.05
# Epoch 552/600, Loss: 0.05
# Epoch 553/600, Loss: 0.05
# Epoch 554/600, Loss: 0.05
# Epoch 555/600, Loss: 0.05
# Epoch 556/600, Loss: 0.05
# Epoch 557/600, Loss: 0.05
# Epoch 558/600, Loss: 0.05
# Epoch 559/600, Loss: 0.05
# Epoch 560/600, Loss: 0.05
# Epoch 561/600, Loss: 0.05
# Epoch 562/600, Loss: 0.05
# Epoch 563/600, Loss: 0.05
# Epoch 564/600, Loss: 0.05
# Epoch 565/600, Loss: 0.05
# Epoch 566/600, Loss: 0.05
# Epoch 567/600, Loss: 0.05
# Epoch 568/600, Loss: 0.05
# Epoch 569/600, Loss: 0.05
# Epoch 570/600, Loss: 0.05
# Epoch 571/600, Loss: 0.05
# Epoch 572/600, Loss: 0.05
# Epoch 573/600, Loss: 0.05
# Epoch 574/600, Loss: 0.05
# Epoch 575/600, Loss: 0.05
# Epoch 576/600, Loss: 0.05
# Epoch 577/600, Loss: 0.05
# Epoch 578/600, Loss: 0.05
# Epoch 579/600, Loss: 0.05
# Epoch 580/600, Loss: 0.05
# Epoch 581/600, Loss: 0.05
# Epoch 582/600, Loss: 0.05
# Epoch 583/600, Loss: 0.05
# Epoch 584/600, Loss: 0.05
# Epoch 585/600, Loss: 0.05
# Epoch 586/600, Loss: 0.05
# Epoch 587/600, Loss: 0.05
# Epoch 588/600, Loss: 0.05
# Epoch 589/600, Loss: 0.05
# Epoch 590/600, Loss: 0.05
# Epoch 591/600, Loss: 0.05
# Epoch 592/600, Loss: 0.05
# Epoch 593/600, Loss: 0.05
# Epoch 594/600, Loss: 0.05
# Epoch 595/600, Loss: 0.05
# Epoch 596/600, Loss: 0.05
# Epoch 597/600, Loss: 0.05
# Epoch 598/600, Loss: 0.05
# Epoch 599/600, Loss: 0.05
# Epoch 600/600, Loss: 0.05

# %%
plt.plot(range(1, len(loss_each_epoch_MLP) + 1), loss_each_epoch_MLP)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('MLP')
plt.show()

# %%
print('Multi Layer Perceptron (Train Accuracy)')
model_evaluation(train_loader, clf_MLP)
# Out:
# Multi Layer Perceptron (Train Accuracy)
# We got 75/445 correct. Accuracy = 16.85%

# %%
print('Multi Layer Perceptron (Test Accuracy)')
model_evaluation(test_loader, clf_MLP)
# Out:
# Multi Layer Perceptron (Test Accuracy)
# We got 17/192 correct. Accuracy = 8.85%

# %%
ROW_IMG, N_ROWS = 3, 2

fig = plt.figure()
for index in range(1, ROW_IMG * N_ROWS + 1):
    plt.subplot(N_ROWS, ROW_IMG, index)
    plt.axis('off')
    plt.imshow(test_dataset[index][0].squeeze(), cmap='gray_r')
    
    with torch.no_grad():
        clf_MLP.eval()
        X = test_dataset[index][0].reshape(test_dataset[index][0].shape[0], -1).to(device)
        _, probs = clf_MLP(X)
    title = f'Predict: {le.inverse_transform([torch.argmax(probs).item()])[0]} ({torch.max(probs * 100):.0f}%)\n True Label: {le.inverse_transform([test_dataset[index][-1]])[0]}'
    
    plt.title(title, fontsize=7)
plt.show()
